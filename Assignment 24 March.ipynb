# %%
#Ans 1:
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#The key feature is fixed acidity ,volatile acidity ,citric acid ,residual sugar,chlorides,freesulphur,density,pH,sulphates,alcohol.
#This feature is determine the quality of wine

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#ANs2:
#Missing the handle the values by finding the mean,median and mode of the features and put the mean or mode or median .
#Advantage is these are directly find by numpy and disdvantage is this value is not correct always for a particular fearture .

# %%
#Ans3:
df1=pd.read_csv("StudentsPerformance.csv")

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#The features is gender,race/ethnicity,parental level of education,lunch,test preparation course.

# %%
df1.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Ans4:
#step:load the dataset 
#Step.Check the null values 
#Step:if the null values is present and replace by the data imputation techniques.
#Step:check the duplicate .if it is drop 
#Step find the statiscal factors by describe.
#step :drop the column that are correlate withh others
#step now the dataset is ready for our model .

# %%
#Ans5:
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.hist(bins=20, figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
#Ans5:
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
scale=StandardScaler()

# %%
X_scale=scale.fit_transform(X)

# %%
X_scale
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.96024611],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.58477711],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.58477711],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.54162988],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.20930812],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.54162988]])

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
pca=PCA()

# %%
df5=pca.fit_transform(X_scale)

# %%
pd.DataFrame(df5)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.619530  0.450950 -1.774454  0.043740  0.067014 -0.913921 -0.161043
# 1    -0.799170  1.856553 -0.911690  0.548066 -0.018392  0.929714 -1.009829
# 2    -0.748479  0.882039 -1.171394  0.411021 -0.043531  0.401473 -0.539553
# 3     2.357673 -0.269976  0.243489 -0.928450 -1.499149 -0.131017  0.344290
# 4    -1.619530  0.450950 -1.774454  0.043740  0.067014 -0.913921 -0.161043
# ...        ...       ...       ...       ...       ...       ...       ...
# 1594 -2.150500  0.814286  0.617063  0.407687 -0.240936  0.054835  0.170812
# 1595 -2.214496  0.893101  1.807402  0.414003  0.119592 -0.674711 -0.607970
# 1596 -1.456129  0.311746  1.124239  0.491877  0.193716 -0.506410 -0.231082
# 1597 -2.270518  0.979791  0.627965  0.639770  0.067735 -0.860408 -0.321487
# 1598 -0.426975 -0.536690  1.628955 -0.391716  0.450482 -0.496154  1.189132
#
#             7         8         9         10
# ...
