# %%
#Ans1: 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#
df.shape
# Out:
# (10683, 11)

# %%
#there are 10683 rows and 11 are columns

# %%
#Ans2:
pd.DataFrame(df['Price'])
# Out:
#        Price
# 0       3897
# 1       7662
# 2      13882
# 3       6218
# 4      13302
# ...      ...
# 10678   4107
# 10679   4145
# 10680   7229
# 10681  12648
# 10682  11753
#
# [10683 rows x 1 columns]

# %%
plt.hist(df['Price'])
# Out:
# (array([6.029e+03, 4.390e+03, 1.820e+02, 6.600e+01, 7.000e+00, 1.000e+00,
#         5.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1759. ,  9534.3, 17309.6, 25084.9, 32860.2, 40635.5, 48410.8,
#         56186.1, 63961.4, 71736.7, 79512. ]),
#  <BarContainer object of 10 artists>)

# %%
#Ans3:
maximum=np.max(df['Price'])

# %%
minimum=np.min(df['Price'])

# %%
maximum,minimum
# Out:
# (79512, 1759)

# %%
#Range(1759-79512)

# %%
#Ans4:
df.corr(method='pearson')
# Out:
#        Price
# Price    1.0

# %%
sns.boxplot(x=df['Price'],y=df['Airline'],data=df)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Airline'>

# %%
#Ans5:Yes and the potential outlier is 50000 to 60000 which is impact my analysis .

# %%
#Ans6:
#By plot the bell curve which define the peak season .
df['month']=df['Date_of_Journey'].str.split('/').str[1]

# %%
df['month']
# Out:
# 0        03
# 1        05
# 2        06
# 3        05
# 4        03
#          ..
# 10678    04
# 10679    04
# 10680    04
# 10681    03
# 10682    05
# Name: month, Length: 10683, dtype: object

# %%
sns.histplot(x=df['month'],y=df['Price'],kde=True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Price'>

# %%
#Ans7:
sns.pairplot(df)

# %%
#ANs8
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Dep_Time', y='Price', data=df)
plt.title('Flight Prices by Departure Location')
plt.xlabel('Departure Location')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Dep_Time', y='Price', data=df)
plt.title('Flight Prices by Departure Time')
plt.xlabel('Departure Time')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Duration', y='Price', data=df)
plt.title('Flight Prices by Duration')
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Airline', y='Price', data=df)
plt.title('Flight Prices by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Duration', y='Price', data=df)
plt.title('Flight Prices by Distance')
plt.xlabel('Distance (km)')
plt.ylabel('Price')
plt.show()

# %%
###Google Playstore

# %%
#Ans9:
df=pd.read_csv('googleplaystore.csv')

# %%
df.shape
# Out:
# (10841, 13)

# %%
#There are 10841 rows and 13 columns

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Ans10:
sns.histplot(x=df['Rating'],y=df['Category'],data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Category'>

# %%
sns.boxplot(x=df['Rating'],y=df['Category'],data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Category'>

# %%
#Ans11:
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#Yes 
df[df.isnull()]
# Out:
#        App Category  Rating Reviews Size Installs Type Price Content Rating  \
# 0      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 1      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 2      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 3      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 4      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# ...    ...      ...     ...     ...  ...      ...  ...   ...            ...
# 10836  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10837  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10838  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10839  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10840  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
#
#       Genres Last Updated Current Ver Android Ver
# ...

# %%
#There are lot of information in null value so these are imapct the dataset .

# %%
#Ans12:
sns.jointplot(x=df['Size'],y=df['Rating'],data=df)

# %%
#Idf the size is increase then rating is increase.

# %%
sns.scatterplot(x=df['Size'],y=df['Rating'],data=df)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rating'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X=df['App']

# %%
X_label=LabelEncoder().fit_transform(X)

# %%
sns.barplot(x=X_label,y=df['Price'],data=df)
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
#ANs14:
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df[['App','Installs']]
# Out:
#                                                      App     Installs
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      10,000+
# 1                                    Coloring book moana     500,000+
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...   5,000,000+
# 3                                  Sketch - Draw & Paint  50,000,000+
# 4                  Pixel Draw - Number Art Coloring Book     100,000+
# ...                                                  ...          ...
# 10836                                   Sya9a Maroc - FR       5,000+
# 10837                   Fr. Mike Schmitz Audio Teachings         100+
# 10838                             Parkinson Exercices FR       1,000+
# 10839                      The SCP Foundation DB fr nn5n       1,000+
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  10,000,000+
#
# [10841 rows x 2 columns]

# %%
#Ans15:
sns.barplot(x=X_label,y=df['Rating'],data=df)
# Out:
# <AxesSubplot:ylabel='Rating'>

# %%
#ANs16:By plot barchart

# %%
#ANs17:

# %%
gg=df['Installs'].str.split('+').str[0]

# %%
par=[]
for i in gg:
    if i=='Free':
        del(i)
    else:
        par.append(i)

# %%
max(par)
# Out:
# '500,000,000'

# %%
if df['Installs']=='500,000,000':
    print
