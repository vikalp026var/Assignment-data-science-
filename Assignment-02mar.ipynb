# %%
#Ans1:Matplotlib is a pakage in python and is used for visualiazation of data .
# bar,hisogram,line,scatter,pi.

# %%
#Ans2:Scatterplot is plot that visualise the data in dotted form .

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y,c='r')

# %%
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Graph")
plt.scatter(x,y,c='r')
plt.show()

# %%
#Ans3:The subplot() function in matplotlib is used to create multiple plots within a single figure. 
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')
axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')
axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')
fig.tight_layout()
plt.show()

# %%
#Ans4:bar plot is used to show the data or raleton between the data in bar grph

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.title("Profit")
# Out:
# Text(0.5, 1.0, 'Profit')

# %%
#Ans5:
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data = [box1, box2]
fig, ax = plt.subplots()
ax.boxplot(data)
plt.xlabel("Data")
plt.ylabel("value")
# Out:
# Text(0, 0.5, 'value')

# %%
#A box plot is a graphical representation of a dataset that displays the median, quartiles, and outliers of the data.
