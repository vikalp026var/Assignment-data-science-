# %%
#Ans1:Flask is library to create API in Python.It is lightweight,higher flaxibility,higher compatibility with latest technologies.
#Ans2: given below:-

# %% [markdown]
# ![title](hello.png)

# %%
#Ans3:App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
#Because it is way that we can asscess the function in pyhton through web browser.

# %%
#Ans4: given below:-

# %%
from IPython.display import Image
Image(filename="welcome.png",width=400,height=400)

# %%
from IPython.display import Image
Image(filename="ABC.png",width=400,height=400)

# %%
#Ans5:Flask is a lightweight Python web framework that provides useful tools and features for creating web applications in the Python Language. 
#
